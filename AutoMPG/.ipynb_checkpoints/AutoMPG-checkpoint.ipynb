# %%
import math
import numpy
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error


cars_names = ['mpg','cylinders','displacement','horsepower','weight','acceleration','model year','origin','car name']

cars = pd.read_table("auto-mpg.data.txt", delim_whitespace=True, names = cars_names)

# %%
cars.shape
# Out:
# (398, 9)

# %%
cars.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %%
cars.head(5)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
filtered_cars = cars[cars["horsepower"] != '?'].copy()

# %%
filtered_cars.shape
# Out:
# (392, 9)

# %%
filtered_cars.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight          float64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
filtered_cars['horsepower'] = filtered_cars['horsepower'].astype('float')

#filtered_cars[:, 'horsepower'] = filtered_cars['horsepower'].astype('float')
# Out:
# /Users/javi/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
columns_to_plot = ['mpg','horsepower','weight','acceleration']
#columns_to_plot = ['mpg','cylinders','displacement','horsepower','weight','acceleration']


axes = pd.tools.plotting.scatter_matrix(filtered_cars[columns_to_plot], alpha=1)
plt.tight_layout()
#plt.savefig('scatter_matrix.png')

# %%
fig = plt.figure(figsize=(5,7))
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)


ax1.scatter(cars["weight"], cars["mpg"])
ax2.scatter(cars["acceleration"], cars["mpg"])


plt.show()

# %%
#lr = LinearRegression()
lr = LinearRegression(fit_intercept=True)

#Remember the [[]], is the data in 1 column
lr.fit(cars[["weight"]], cars[["mpg"]])
predictions = lr.predict(cars[["weight"]])

#mean_squared_error
mse = mean_squared_error(cars[["mpg"]], predictions)

print(mse)
rmse = math.sqrt(mse)
print(rmse)
# Out:
# 18.7809397346
# 4.333698159150957

# %%
plt.scatter(cars["weight"], cars["mpg"], c='red')
#plt.scatter(cars["weight"], predictions, c='blue')
plt.plot(cars["weight"], predictions, color='blue',
         linewidth=3)

# %%
# The coefficients
print('Coefficients: ', lr.coef_)
# The intercept
#print('Intercept: ', lr.intercep_)
# The mean square error
print("Residual sum of squares: %.2f" % numpy.mean((predictions - cars[["weight"]]) ** 2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % lr.score(cars[["weight"]], cars[["mpg"]]))
# Out:
# Coefficients:  [[-0.00767661]]
# Residual sum of squares: 9410642.89
# Variance score: 0.69
